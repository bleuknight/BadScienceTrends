# %%
import pandas as pd

#this is the file which links contains all query terms
terms = pd.read_csv("queryTerms.csv")
queryTerms = list(terms['term1'])

# %%
queryTerms
# Out:
# ['in-vitro+in-vivo+correlation',
#  'Animal model',
#  'animal+Model ',
#  'Antibody',
#  'bioavailability',
#  'bioavailable',
#  'Bio-identical',
#  'case+study',
#  'case+study',
#  'Cell+line',
#  'Clinical+Trials',
#  'Clone',
#  'coaching',
#  'Conflict+of+Interest ',
#  'confounding+factor',
#  'Contamination',
#  'data+quality',
#  'dosage',
#  'Dose-dependent',
#  'dosing',
#  'drug+interaction',
#  'Gender',
#  'general+conclusion',
#  'generalized+conclusion',
#  'human+error',
#  'indirect+measurement',
#  'insufficient+information',
#  'long+term+study',
#  'misinterpretation',
#  'off-label',
#  'omission',
#  'phase+III+trials',
#  'pilot+study',
#  'placebo',
#  'plasmid',
#  'poor+quality',
#  'Positive+control',
#  'qualitative+data',
#  'quality',
#  'Questionairre',
#  'Reproducibility',
#  'Reproducible+Results',
#  'Sensitivity',
#  'short +term + study',
#  'side+effects',
#  'Specificity',
#  'speculation',
#  'Strain',
#  'sub-threshold',
#  'Survey',
#  'survey',
#  'transparency',
#  'wrong+conclusion']

# %%
retracted = ('"Retracted Publication"[PT] AND "' + Q + '"[TIAB]' for Q in queryTerms)
retractedList = ['"Retracted Publication"[PT] AND "' + Q +'"[TIAB]' for Q in queryTerms]
print(retractedList)
# Out:
# ['"Retracted Publication"[PT] AND "in-vitro+in-vivo+correlation"[TIAB]', '"Retracted Publication"[PT] AND "Animal model"[TIAB]', '"Retracted Publication"[PT] AND "animal+Model "[TIAB]', '"Retracted Publication"[PT] AND "Antibody"[TIAB]', '"Retracted Publication"[PT] AND "bioavailability"[TIAB]', '"Retracted Publication"[PT] AND "bioavailable"[TIAB]', '"Retracted Publication"[PT] AND "Bio-identical"[TIAB]', '"Retracted Publication"[PT] AND "case+study"[TIAB]', '"Retracted Publication"[PT] AND "case+study"[TIAB]', '"Retracted Publication"[PT] AND "Cell+line"[TIAB]', '"Retracted Publication"[PT] AND "Clinical+Trials"[TIAB]', '"Retracted Publication"[PT] AND "Clone"[TIAB]', '"Retracted Publication"[PT] AND "coaching"[TIAB]', '"Retracted Publication"[PT] AND "Conflict+of+Interest "[TIAB]', '"Retracted Publication"[PT] AND "confounding+factor"[TIAB]', '"Retracted Publication"[PT] AND "Contamination"[TIAB]', '"Retracted Publication"[PT] AND "data+quality"[TIAB]', '"Retracted Publication"[PT] AND "dosage"[TIAB]', '"Retracted Publication"[PT] AND "Dose-dependent"[TIAB]', '"Retracted Publication"[PT] AND "dosing"[TIAB]', '"Retracted Publication"[PT] AND "drug+interaction"[TIAB]', '"Retracted Publication"[PT] AND "Gender"[TIAB]', '"Retracted Publication"[PT] AND "general+conclusion"[TIAB]', '"Retracted Publication"[PT] AND "generalized+conclusion"[TIAB]', '"Retracted Publication"[PT] AND "human+error"[TIAB]', '"Retracted Publication"[PT] AND "indirect+measurement"[TIAB]', '"Retracted Publication"[PT] AND "insufficient+information"[TIAB]', '"Retracted Publication"[PT] AND "long+term+study"[TIAB]', '"Retracted Publication"[PT] AND "misinterpretation"[TIAB]', '"Retracted Publication"[PT] AND "off-label"[TIAB]', '"Retracted Publication"[PT] AND "omission"[TIAB]', '"Retracted Publication"[PT] AND "phase+III+trials"[TIAB]', '"Retracted Publication"[PT] AND "pilot+study"[TIAB]', '"Retracted Publication"[PT] AND "placebo"[TIAB]', '"Retracted Publication"[PT] AND "plasmid"[TIAB]', '"Retracted Publication"[PT] AND "poor+quality"[TIAB]', '"Retracted Publication"[PT] AND "Positive+control"[TIAB]', '"Retracted Publication"[PT] AND "qualitative+data"[TIAB]', '"Retracted Publication"[PT] AND "quality"[TIAB]', '"Retracted Publication"[PT] AND "Questionairre"[TIAB]', '"Retracted Publication"[PT] AND "Reproducibility"[TIAB]', '"Retracted Publication"[PT] AND "Reproducible+Results"[TIAB]', '"Retracted Publication"[PT] AND "Sensitivity"[TIAB]', '"Retracted Publication"[PT] AND "short +term + study"[TIAB]', '"Retracted Publication"[PT] AND "side+effects"[TIAB]', '"Retracted Publication"[PT] AND "Specificity"[TIAB]', '"Retracted Publication"[PT] AND "speculation"[TIAB]', '"Retracted Publication"[PT] AND "Strain"[TIAB]', '"Retracted Publication"[PT] AND "sub-threshold"[TIAB]', '"Retracted Publication"[PT] AND "Survey"[TIAB]', '"Retracted Publication"[PT] AND "survey"[TIAB]', '"Retracted Publication"[PT] AND "transparency"[TIAB]', '"Retracted Publication"[PT] AND "wrong+conclusion"[TIAB]']

# %%
from Bio import Entrez
Entrez.email = "scientistbleu@gmail.com"
retractedCount = []
for r in retracted:
    handle = Entrez.esearch(db = "pubmed", term = r, retmax = 100000)
    record = Entrez.read(handle)
    count = record["Count"]
    retractedCount.append(count)
print(retractedCount)
# Out:
# ['0', '38', '38', '160', '19', '4', '0', '15', '15', '184', '57', '27', '0', '1', '0', '14', '0', '26', '95', '10', '0', '60', '0', '0', '0', '0', '0', '1', '0', '0', '6', '2', '21', '158', '42', '2', '8', '1', '155', '0', '14', '0', '218', '0', '77', '123', '4', '110', '0', '55', '55', '0', '0']

# %%
countRetracted = dict(zip(queryTerms, retractedCount))
countRetracted
# Out:
# {'Animal model': '38',
#  'Antibody': '160',
#  'Bio-identical': '0',
#  'Cell+line': '184',
#  'Clinical+Trials': '57',
#  'Clone': '27',
#  'Conflict+of+Interest ': '1',
#  'Contamination': '14',
#  'Dose-dependent': '95',
#  'Gender': '60',
#  'Positive+control': '8',
#  'Questionairre': '0',
#  'Reproducibility': '14',
#  'Reproducible+Results': '0',
#  'Sensitivity': '218',
#  'Specificity': '123',
#  'Strain': '110',
#  'Survey': '55',
#  'animal+Model ': '38',
#  'bioavailability': '19',
#  'bioavailable': '4',
#  'case+study': '15',
#  'coaching': '0',
#  'confounding+factor': '0',
#  'data+quality': '0',
#  'dosage': '26',
#  'dosing': '10',
#  'drug+interaction': '0',
#  'general+conclusion': '0',
#  'generalized+conclusion': '0',
#  'human+error': '0',
#  'in-vitro+in-vivo+correlation': '0',
#  'indirect+measurement': '0',
#  'insufficient+information': '0',
#  'long+term+study': '1',
#  'misinterpretation': '0',
#  'off-label': '0',
#  'omission': '6',
#  'phase+III+trials': '2',
#  'pilot+study': '21',
#  'placebo': '158',
#  'plasmid': '42',
#  'poor+quality': '2',
#  'qualitative+data': '1',
#  'quality': '155',
#  'short +term + study': '0',
#  'side+effects': '77',
#  'speculation': '4',
#  'sub-threshold': '0',
#  'survey': '55',
#  'transparency': '0',
#  'wrong+conclusion': '0'}

# %%
from Bio import Entrez
Entrez.email = "happylittleaccident@gmail.com"
#creates open dictionary to store PMID with query term
retractedID = {}
def getRetractedIDs(QTs):
    for Q in QTs:
        t = '"Retracted Publication"[PT] + AND "' + Q + '"[TIAB]' 
        handle = Entrez.esearch(db = "pubmed", term = t, retmax = 100000)
        record = Entrez.read(handle)
        PMIDS = record["IdList"]
        retractedID[Q] = PMIDS

getRetractedIDs(queryTerms)
print(retractedID)
# Out:
# {'case+study': ['28734458', '25663403', '25119293', '24304430', '23869624', '23256543', '22887471', '22431929', '21752810', '20588141', '20577784', '19387376', '18321333', '17892576', '17470215'], 'Dose-dependent': ['28121356', '27155204', '27039209', '26165557', '26074732', '26009496', '25712731', '25448881', '25337571', '25326893', '25231122', '24900970', '24792235', '24708487', '24589031', '24587321', '24239290', '24122418', '24081676', '23936343', '23573102', '23492364', '23349038', '22621398', '22428884', '22246399', '21961649', '21914790', '21750577', '21687510', '21625550', '21243427', '21129477', '21046465', '20840810', '20370940', '20123013', '19782726', '19657716', '19285023', '18693175', '18456410', '18424723', '18339371', '18339155', '18292803', '18224727', '17977947', '17918160', '17911405', '17450507', '17395477', '17267205', '17241528', '17133340', '17080405', '16891626', '16775809', '16537533', '16466641', '16413539', '16207520', '16192765', '16009522', '15934020', '15763381', '15740897', '15276867', '15269168', '15177893', '15076954', '12651654', '12169113', '12115878', '12115185', '11834606', '11714798', '11375852', '11226115', '11102966', '10925314', '9780201', '9601702', '23839547', '23839884', '23839836', '7955120', '7521696', '8142647', '7679698', '1752960', '1912585', '1996082', '1967819', '2769271'], 'dosing': ['27769522', '26628976', '25596088', '24653606', '24179960', '24132736', '18368379', '11206594', '10357331', '9421334'], 'omission': ['27060554', '25889486', '16963789', '15084597', '12680748', '9685252'], 'in-vitro+in-vivo+correlation': [], 'general+conclusion': [], 'confounding+factor': [], 'data+quality': [], 'Animal model': ['27483303', '27460898', '26889707', '25995336', '25851468', '25621044', '25381057', '24762603', '24656405', '24077839', '23947821', '23941603', '23744736', '23030292', '22921965', '22525440', '22387856', '22364277', '22213426', '21854183', '22833948', '20879957', '20124219', '19785755', '19607689', '17611720', '16368125', '15642590', '15208318', '14977841', '11102966', '10642298', '10618412', '10559146', '9328234', '8393056', '1400454', '1979954'], 'misinterpretation': [], 'quality': ['29210313', '29072571', '28514309', '28410782', '27749538', '27616881', '27548421', '27442160', '27428477', '27168883', '27005886', '26997557', '26844455', '26843732', '26756004', '28331512', '26542344', '26504894', '26445532', '26408135', '26361340', '26353858', '26215876', '26159007', '26147251', '26103185', '25946735', '25897331', '25889956', '25738055', '25695571', '26958267', '25548771', '25424784', '25252793', '25143362', '25136662', '25087939', '25052012', '25003729', '24977099', '24969506', '24940708', '24872563', '24835911', '24675398', '24611076', '24600980', '24580774', '24456256', '24445398', '24325911', '24242260', '24237003', '24079711', '23976842', '23884831', '23866960', '23865135', '23761553', '23736093', '23541262', '23535800', '23481049', '23385271', '23274035', '23257126', '23173650', '23173612', '23113397', '22991669', '22893834', '22666147', '22640574', '22578515', '22567051', '22514562', '22476205', '22318734', '22298504', '22278973', '22229754', '22096631', '22029902', '22023718', '21983222', '21975687', '21900434', '21860315', '23140713', '21531487', '21525538', '21488394', '21474762', '21341971', '21294695', '20958973', '20635202', '20532074', '20414325', '20332269', '20215681', '20101332', '20066585', '20035226', '20002437', '20002225', '19895380', '19693644', '19607689', '19471880', '19371446', '19189065', '19183482', '19181022', '19105710', '18806057', '18644686', '18402204', '18382681', '18337472', '18227494', '18022165', '17965330', '17918285', '17701044', '17043678', '16943966', '16912754', '16873043', '16639069', '16594919', '16557440', '16372008', '16342351', '16322903', '15824067', '15723591', '15495094', '15154073', '15041987', '12974429', '12761696', '12670382', '12117884', '12029431', '11527656', '10915617', '10875912', '10453151', '10195272', '10195271', ...

# %%
df_Retracted = pd.DataFrame([countRetracted, retractedID]).T
df_Retracted.columns = ['d{}'.format(i) for i, col in enumerate(df_Retracted, 1)]
df_Retracted
# Out:
#                                d1  \
# Animal model                   38
# Antibody                      160
# Bio-identical                   0
# Cell+line                     184
# Clinical+Trials                57
# Clone                          27
# Conflict+of+Interest            1
# Contamination                  14
# Dose-dependent                 95
# Gender                         60
# Positive+control                8
# Questionairre                   0
# Reproducibility                14
# Reproducible+Results            0
# Sensitivity                   218
# Specificity                   123
# Strain                        110
# Survey                         55
# animal+Model                   38
# bioavailability                19
# bioavailable                    4
# case+study                     15
# coaching                        0
# confounding+factor              0
# data+quality                    0
# dosage                         26
# dosing                         10
# drug+interaction                0
# general+conclusion              0
# generalized+conclusion          0
# human+error                     0
# in-vitro+in-vivo+correlation    0
# indirect+measurement            0
# insufficient+information        0
# long+term+study                 1
# misinterpretation               0
# off-label                       0
# omission                        6
# phase+III+trials                2
# pilot+study                    21
# placebo                       158
# plasmid                        42
# poor+quality                    2
# qualitative+data                1
# quality                       155
# short +term + study             0
# side+effects                   77
# speculation                     4
# sub-threshold                   0
# survey                         55
# transparency                    0
# wrong+conclusion                0
#
#                                                                              d2
# Animal model                  [27483303, 27460898, 26889707, 25995336, 25851...
# Antibody                      [28595908, 28264024, 27902473, 27681397, 27578...
# Bio-identical                                                                []
# Cell+line                     [28611662, 28370854, 28243335, 27936486, 27173...
# Clinical+Trials               [28614379, 28182034, 28059665, 28040596, 27942...
# Clone                         [28783371, 25381057, 25374426, 24385585, 23463...
# Conflict+of+Interest                                                 [28202934]
# Contamination                 [27135839, 26448745, 25663403, 25412353, 25351...
# Dose-dependent                [28121356, 27155204, 27039209, 26165557, 26074...
# Gender                        [28964001, 28083053, 28042118, 27242466, 26715...
# Positive+control              [23365606, 23178309, 22853996, 21453783, 21061...
# Questionairre                                                                []
# Reproducibility               [27312347, 27005886, 26411479, 25484052, 22559...
# Reproducible+Results                                                         []
# Sensitivity                   [28794294, 28788903, 27775785, 27749538, 27134...
# Specificity                   [28794294, 28232911, 27775785, 27165857, 27134...
# Strain                        [29046721, 27617005, 27203611, 28787919, 26628...
# Survey                        [28745809, 28506377, 28193790, 28083053, 28057...
# animal+Model                  [27483303, 27460898, 26889707, 25995336, 25851...
# bioavailability               [27862525, 29648728, 23800858, 23286295, 22747...
# bioavailable                           [25977697, 23286295, 22378937, 19735646]
# case+study                    [28734458, 25663403, 25119293, 24304430, 23869...
# coaching                                                                     []
# confounding+factor                                                           []
# data+quality                                                                 []
# dosage                        [26474031, 26074732, 26064224, 25477256, 24132...
# dosing                        [27769522, 26628976, 25596088, 24653606, 24179...
# drug+interaction                                                             []
# general+conclusion                                                           []
# generalized+conclusion                                                       []
# human+error                                                                  []
# in-vitro+in-vivo+correlation                                                 []
# indirect+measurement                                                         []
# insufficient+information                                                     []
# long+term+study                                                      [21376079]
# misinterpretation                                                            []
# off-label                                                                    []
# omission                      [27060554, 25889486, 16963789, 15084597, 12680...
# phase+III+trials                                           [22912868, 21102589]
# pilot+study                   [28237802, 27681397, 27421008, 26980236, 26673...
# placebo                       [28514309, 28182513, 27471887, 26997557, 26844...
# plasmid                       [26958809, 25135431, 24992962, 24101244, 23945...
# poor+quality                                               [23976842, 22298504]
# qualitative+data                                                     [18790478]
# quality                       [29210313, 29072571, 28514309, 28410782, 27749...
# short +term + study                                                          []
# side+effects                  [27749538, 27373757, 27227402, 27177293, 26733...
# speculation                            [24705863, 19466205, 16938870, 12446324]
# sub-threshold                                                                []
# survey                        [28745809, 28506377, 28193790, 28083053, 28057...
# transparency                                                                 []
# wrong+conclusion                                                             []

# %%
df_Retracted.to_csv("retractedTYPE.csv")

# %%
from Bio import Entrez
Entrez.email = "happylittleaccident@gmail.com"
#creates open dictionary to store PMID with query term
retractedYear = {}
def getRetractedYears(QTs):
    for Q in QTs:
        t = 'Retracted Publication[PT] + AND "' + Q + '"[TIAB]' 
        handle = Entrez.esearch(db = "pubmed", term = t, retmax = 100000)
        record = Entrez.read(handle)
        PMIDS = record["IdList"]
        retractedID[Q] = PMIDS

getRetractedIDs(queryTerms)
print(retractedID)
# Out:
# {'case+study': ['29056790', '27956822', '29451542', '26439083', '24714396', '23054278', '25215033', '20136577', '15998609', '10429438', '2284685'], 'Dose-dependent': ['28444745', '28121356', '27039209', '26165557', '23051153', '21541247', '18474415', '16806150', '16379023', '12871374', '12417182', '10704379', '10400315', '10328761', '10103101', '9655183', '23839547', '23839884', '23839836', '1487498', '1507037', '2148946', '2116423', '2370296', '3367396', '3127855', '3443111'], 'dosing': ['28384800', '27769522', '16326378', '15083263', '14608265', '856971'], 'omission': ['27060554', '16893357', '2486063'], 'in-vitro+in-vivo+correlation': [], 'general+conclusion': ['2891681'], 'confounding+factor': [], 'data+quality': [], 'Animal model': ['28272927', '24656405', '23917953', '23509848', '22152220', '21938374', '21717264', '21445691', '21046162', '20856155', '20432205', '19933535', '19709796', '19434747', '18931216', '17637406', '17543299', '17459566', '17156366', '16251122', '15502048', '14530193', '12107773', '1467152', '3257305', '3789599'], 'misinterpretation': ['27751806'], 'quality': ['29540088', '29516389', '29514510', '29295508', '29273256', '29210313', '28970995', '28958817', '28820231', '28771429', '28658253', '27848190', '27746994', '27476082', '27428477', '27369181', '27271789', '27000421', '26997557', '26665095', '26103185', '25802866', '25677528', '25654147', '25621247', '25504843', '25496354', '25433345', '25243705', '25087939', '25035389', '24976395', '24921111', '24789127', '24745316', '24456256', '24224282', '24054975', '24049551', '24022761', '24004521', '23881659', '23076906', '22521394', '22385006', '22184610', '22083047', '23140713', '21692799', '21341971', '21324233', '23169028', '21099575', '21092665', '20980012', '20485766', '20354867', '20146010', '20002437', '19928080', '19462847', '19328485', '19246874', '19120781', '18002239', '17042025', '16910604', '16548734', '16517361', '16224689', '15915143', '15885325', '15716993', '15548620', '15080865', '14673523', '12171229', '11889395', '11264585', '10659260', '10524434', '10488264', '10357133', '9356936', '9863148', '7476720', '7918523', '1795080', '3481167', '4056861', '6750672', '1067147'], 'Clone': ['28783371', '15599052', '10085261', '4607944'], 'drug+interaction': [], 'coaching': [], 'Contamination': ['27818683', '27000421', '24928194', '24598373', '22818188', '22743633', '20166838', '20063015', '18091414', '15585294', '14673523', '10550028', '10364862', '9921315', '9341276', '8666769', '3400036'], 'Bio-identical': [], 'human+error': [], 'wrong+conclusion': [], 'short +term + study': [], 'phase+III+trials': [], 'Conflict+of+Interest ': ['28447746', '24796938'], 'transparency': ['29403283', '28151522', '27881524', '26507205', '25510233', '21343631', '18389086'], 'generalized+conclusion': [], 'Gender': ['29531022', '29049633', '28455482', '27790473', '26083381', '24970288', '24349783', '21560689', '21505918', '25132890', '20625740', '20228659', '20094068', '19499278', '18474156', '17478283', '17324263', '16910604', '16202047'], 'bioavailability': [], 'Positive+control': ['17536925'], 'qualitative+data': [], 'bioavailable': [], 'Survey': ['29451549', '29403283', '28840875', '28683764', '27454761', '27140508', '26252752', '26185672', '27345871', '24754060', '24754059', '24708140', '24456256', '23652169', '23115617', '22423330', '22331199', '21544560', '20222787', '17324263', '16905059', '15387154', '11319406', '10557828', '9921315', '9345157', '1495051', '1544030', '3147062', '4084832', '31726'], 'off-label': [], 'Antibody': ['29600441', '29581415', '28734992', '27129395', '25434797', '25383253', '25362562', '25227305', '24560420', '24182579', '23046996', '22911094', '22016880', '20176790', '17213796', '16840998', '16816384', '16364653', '16167198', '15953180', '12148241', '12119019', '10845892', '10704379', '9172076', '9112674', '7654601', '7698984', '7869108', '8345105', '7682966', '1473160', '1370314', '1662283', '2196568', '2399808', '2729610', '245557 ...

# %%
retracted_PMIDs = set().union(*retractedID.values())
len(retracted_PMIDs)
# Out:
# 1410

# %%
retracted_years= {}

#creates list to store entries without abstract text
without_year_ret = []

Entrez.email = 'scientistbleu@gmail.com'

handle = Entrez.efetch(db="pubmed", id=','.join(map(str, retracted_PMIDs)),
                       rettype="xml", retmode="text")
records = Entrez.read(handle)
for pubmed_article in records['PubmedArticle']:
    pmid = int(str(pubmed_article['MedlineCitation']['PMID']))
    year = pubmed_article['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']
    if 'Year' in year:
        pubYear = year['Year']
        retracted_years[pmid] = pubYear
    else:
       without_year_ret.append(pmid)

print(retracted_years)
# Out:
# {9113601: '1997', 26408963: '2016', 10944516: '2000', 28514309: '2017', 19371446: '2009', 17516552: '2007', 19908618: '2009', 16322903: '2006', 11952142: '2002', 27471887: '2016', 28059665: '2017', 17450507: '2007', 22427667: '2012', 15284244: '2004', 24587321: '2014', 16803864: '2006', 20213764: '2010', 27203611: '2016', 24551453: '2014', 21704741: '2011', 10932255: '2000', 7955120: '1994', 24946722: '2014', 25209179: '2014', 16033828: '2005', 19202085: '2009', 23257126: '2012', 17230513: '2007', 6985768: '1980', 16840747: '2006', 16342351: '2005', 20451373: '2010', 23365678: '2013', 12974429: '2003', 24385585: '2014', 21516347: '2011', 3473468: '1987', 20234302: '2010', 11710530: '2001', 26269763: '2015', 23271362: '2013', 26601276: '2015', 25995336: '2015', 17535051: '2003', 19693644: '2010', 24455245: '2013', 18790478: '2009', 9773135: '1998', 24116023: '2013', 22065926: '2011', 17114467: '2006', 24242260: '2013', 20421646: '2010', 22798424: '2012', 9603161: '1998', 25712731: '2015', 11100731: '2000', 23971938: '2013', 23963747: '2013', 19122277: '2009', 11821158: '2002', 23418897: '2013', 21106792: '2011', 25695571: '2015', 15144295: '2004', 17267205: '2007', 26423405: '2016', 18165437: '2008', 21158857: '2011', 27168883: '2016', 22741108: '2011', 22364277: '2012', 18790523: '2008', 15872124: '2005', 10095978: '1998', 12935295: '2003', 21687510: '2011', 18337472: '2008', 17223697: '2007', 2993656: '1985', 17535111: '2007', 25477256: '2014', 19607689: '2009', 19136650: '2009', 22567051: '2011', 2214028: '1990', 18514061: '2008', 27058318: '2016', 21547151: '2011', 19718288: '2007', 16040081: '2006', 14871577: '2004', 28595908: '2017', 26568859: '2015', 24397981: '2014', 10453151: '1999', 25851468: '2015', 20060322: '2010', 19785755: '2009', 17367204: '2007', 17182885: '2007', 22833948: '2011', 28788903: '2017', 20067456: '2010', 6171369: '1981', 19933356: '2010', 25319597: '2014', 28057775: '2017', 16898225: '2006', 25395378: '2014', 18018483: '2007', 17701044: '2007', 15882421: '2005', 9689270: '1998', 15642807: '2005', 25596088: '2015', 14530932: '1999', 25003729: '2014', 18060319: '2008', 27373757: '2016', 16980158: '2006', 25108671: '2015', 21862592: '2011', 25381057: '2014', 26353858: '2016', 17911499: '2007', 7923908: '1994', 23908550: '2013', 19693769: '2009', 7541111: '1995', 15024332: '2004', 16963789: '2006', 19237581: '2009', 21252304: '2011', 24082641: '2013', 28352722: '2015', 20101332: '2009', 16409294: '2006', 20105430: '2010', 21854183: '2012', 25663403: '2015', 27312347: '2016', 26003676: '2015', 19380445: '2009', 17043678: '2007', 16230623: '2005', 23744736: '2013', 24319696: '2013', 18292803: '2008', 19086961: '2008', 12024037: '2002', 22444263: '2010', 24101244: '2014', 24762603: '2014', 7679698: '1993', 11714798: '2001', 16738545: '2006', 16920823: '2006', 22056957: '2011', 12454141: '2002', 25324543: '2014', 18794197: '2009', 9314560: '1997', 16557440: '2006', 9509207: '1998', 24611076: '2014', 21129477: '2011', 21283078: '2011', 26542344: '2015', 17690890: '2007', 18704087: '2008', 28121356: '2017', 11146789: '2001', 10993934: '2000', 22033453: '2011', 17965330: '2008', 10696980: '2000', 25063470: '2015', 18524889: '2008', 24835911: '2014', 25374426: '2015', 11182366: '2001', 11714847: '2001', 21291296: '2011', 22806817: '2012', 15970594: '2005', 23064867: '2013', 18227494: '2008', 22993191: '2012', 16372008: '2005', 9771305: '1998', 14557482: '2003', 24708487: '2014', 19077420: '2008', 16088114: '2005', 26345774: '2015', 18821853: '2009', 22593708: '2012', 15456561: '2004', 16009522: '2005', 23906611: '2013', 26673826: '2015', 12370229: '2002', 24465718: '2014', 22249783: '2012', 2089274: '1990', 16832828: '2006', 25932170: '2015', 12538174: '2003', 8700981: '1996', 21151908: '2010', 27173188: '2016', 24101190: '2014', 19657031: '2009', 10195272: '1999', 25903433: '2015', 27060554: '2016', 18693175: '2008', 14645581: '2003', 11139469: '2001', 27421008: '2016', 24408401: '2014', 20584786: '2010', 236 ...

# %%
retracted_abstracts = {}

#creates list to store entries without abstract text
without_abstract_ret = []

Entrez.email = 'scientistbleu@gmail.com'

handle = Entrez.efetch(db="pubmed", id=','.join(map(str, retracted_PMIDs)),
                       rettype="xml", retmode="text")
records = Entrez.read(handle)
for pubmed_article in records['PubmedArticle']:
    pmid = int(str(pubmed_article['MedlineCitation']['PMID']))
    article = pubmed_article['MedlineCitation']['Article']
    if 'Abstract' in article:
        abstract = article['Abstract']['AbstractText'][0]
        retracted_abstracts[pmid] = abstract
    else:
       without_abstract_ret.append(pmid)

print(retracted_abstracts)

# %%
import json
import pandas as pd
with open('retracted.txt', 'w') as outfile:
    json.dump(retracted_abstracts, outfile)
with open('retracted_noAbs.txt', 'w') as outfile:
    json.dump(without_abstract_ret, outfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9ae89ae92b58> in <module>()
#       2 import pandas as pd
#       3 with open('retracted.txt', 'w') as outfile:
# ----> 4     json.dump(retracted_abstracts, outfile)
#       5 with open('retracted_noAbs.txt', 'w') as outfile:
#       6     json.dump(without_abstract_ret, outfile)
#
# NameError: name 'retracted_abstracts' is not defined

# %%
df_RetractedYears = pd.DataFrame(retracted_years, index = [1]).T

# %%
df_RetractedYears.to_csv("retractedYears.csv")
