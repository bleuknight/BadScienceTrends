# %%
import pandas as pd
df = pd.read_csv("conflictCount.csv")
df
# Out:
#                       Unnamed: 0  unjustified  contradictoryReports  \
# 0                        quality          160                    14
# 1                    Sensitivity           69                    30
# 2                       Antibody           15                    14
# 3                         Strain            7                     9
# 4                    Specificity           43                    15
# 5                         Survey           81                     2
# 6                         survey           81                     2
# 7                 Dose-dependent            3                    10
# 8                   Animal model            2                     1
# 9                  animal+Model             2                     1
# 10                     Cell+line            1                    12
# 11               Clinical+Trials           48                     6
# 12                  side+effects           40                     2
# ...

# %%
conflictingData = pd.read_csv("conflictingData.csv")
conflictingData
# Out:
#                       Unnamed: 0   d1  \
# 0                   Animal model   27
# 1                       Antibody  116
# 2                  Bio-identical    0
# 3                      Cell+line   40
# 4                Clinical+Trials  142
# 5                          Clone   11
# 6          Conflict+of+Interest     2
# 7                  Contamination   10
# 8                 Dose-dependent   34
# 9                         Gender  127
# 10              Positive+control    8
# 11                 Questionairre    0
# 12               Reproducibility   13
# 13          Reproducible+Results    1
# 14                   Sensitivity  164
# 15                   Specificity   90
# 16                        Strain   53
# 17                        Survey   49
# 18                 animal+Model    27
# 19               bioavailability   11
# 20                  bioavailable    4
# 21                    case+study    4
# 22                      coaching    1
# ...

# %%
conflictingReports = pd.read_csv("conflictingReports.csv")
conflictingReports
# Out:
#                       Unnamed: 0   d1  \
# 0                   Animal model   16
# 1                       Antibody   99
# 2                  Bio-identical    0
# 3                      Cell+line   41
# 4                Clinical+Trials   57
# 5                          Clone    5
# 6          Conflict+of+Interest     1
# 7                  Contamination   11
# 8                 Dose-dependent   32
# 9                         Gender   62
# 10              Positive+control    4
# 11                 Questionairre    0
# 12               Reproducibility    9
# 13          Reproducible+Results    0
# 14                   Sensitivity  152
# 15                   Specificity   77
# 16                        Strain   53
# 17                        Survey   30
# 18                 animal+Model    16
# 19               bioavailability   11
# 20                  bioavailable    1
# 21                    case+study    2
# 22                      coaching    0
# ...
